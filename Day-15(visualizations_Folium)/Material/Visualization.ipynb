# %%
#install and then import matplotlib
import matplotlib.pyplot as plt

# %%
#matplotlib to render plots in the notebook
# %matplotlib inline

# %%
x = [-3, 5, 7]

# %%
y = [10, 2, 5]

# %%
fig = plt.figure(figsize=(15,3))

plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.suptitle('Sales Comaprison', size=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'Sales Comaprison')

# %%
#fig.savefig('example.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### How to change the plot size

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.set_size_inches(14, 4)

# %%
fig

# %% [markdown]
# The subplots function returns a two-item tuple object containing the Figure and one
# or more Axes objects (here it is just one), which is unpacked into the variables fig
# and ax.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# #### Let us see matplotlib hierarchy

# %%
#differentiate the Figure from the Axes, we can give each one a unique facecolor
#Matplotlib accepts a variety of different input types for color. Approximately
#140 HTML colors are supported by their string name

# %%
fig.set_facecolor('.7')

# %%
ax.set_facecolor('.5')

# %%
fig

# %%
#let's take a look at .get_children method
#The spines represent the databoundaries and are the four physical lines that you see bordering the darker gray
#The x and y axis objects contain the ticks and their labels and the label of the entire axis

ax_children = ax.get_children()
ax_children
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
spines = ax.spines

# %%
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x11ae25250>),
#              ('right', <matplotlib.spines.Spine at 0x11ac7cd10>),
#              ('bottom', <matplotlib.spines.Spine at 0x11ac7c4d0>),
#              ('top', <matplotlib.spines.Spine at 0x11ac7c050>)])

# %%
#Let us work with spines
spine_left = spines['left']
spine_left.set_position(('outward', -50))
spine_left.set_linewidth(10)
spine_bottom = spines['bottom']

# %%
fig

# %%
#let's focus on the axis objects
#We can access each axis through the .xaxis and .yaxis attributes. 
#Some axis properties are also available with the Axes object.

# %%
ax.xaxis.grid(True, which='major', linewidth=2,color='black', linestyle='--')

# %%
fig

# %%
ax.xaxis.set_label_text('X Axis', family='Verdana',fontsize=15)
ax.set_ylabel('Y Axis', family='Gotham', fontsize=20)
# Out:
# Text(38.19999999999999, 0.5, 'Y Axis')

# %%
fig
# Out:
# findfont: Font family ['Gotham'] not found. Falling back to DejaVu Sans.

# %%
#Subplots
plot_objects = plt.subplots(nrows=1, ncols=1)

# %%
plot_objects
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
type(plot_objects)
# Out:
# tuple

# %%
fig = plot_objects[0]

# %%
ax = plot_objects[1]

# %%
fig

# %%
# More than one Axes with plt.subplots, then the second item in the tuple is a NumPy array containing all the Axes
fig, axs = plt.subplots(2, 4)

# %%
axs

# %% [markdown]
# #### Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
# table 
pd.crosstab(mtcars.gear,mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
# bar plot between 2 different categories 
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gear'>

# %%
mtcars["gear"].value_counts()
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
import seaborn as sns 
# getting boxplot of mpg with respect to each category of gears 
sns.boxplot(x="gear",y="mpg",data=mtcars)
# Out:
# <AxesSubplot:xlabel='gear', ylabel='mpg'>

# %%
sns.pairplot(mtcars.iloc[:,0:4]) # histogram of each column and 
# scatter plot of each variable with respect to other columns

# %%
plt.plot(mtcars.mpg,"rs-") # scatter plot of single variable

# %%
plt.plot(mtcars.mpg,"ro-")

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)## scatter plot of two variables

# %%
# Graphical Representation of data
#import matplotlib.pyplot as plt
# Histogram
plt.hist(mtcars['mpg'])
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars['mpg'],facecolor ="peru",edgecolor ="blue",bins =5)
#creates histogram with 5bins and colours filled init.
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %%
#Boxplot
#help(plt.boxplot)
plt.boxplot(mtcars['mpg'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12b4ad350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12b4ada90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12b4a4f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x12b4b9390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12b4b97d0>],
#  'means': []}

# %%
plt.boxplot(mtcars['mpg'],vert =False);plt.ylabel("MPG");plt.xlabel("Boxplot");plt.title("Boxplot")  # for vertical
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
plt.boxplot(mtcars['mpg'],1,'rs',1)# For Horizontal
#help(plt.boxplot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12b6a91d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12b6a9a50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12b69fdd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12b6b3350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12b6b3790>],
#  'means': []}

# %%
# Barplot
# bar plot we need height i.e value of each data
# left - for starting point of each bar plot of data on X-axis(Horizontal axis). Here data is mba['gmat']
index = np.arange(32) # np.arange(a)  = > creates consecutive numbers from 
# 0 to 772 

mtcars.shape # dimensions of data frame 

plt.bar(height =mtcars['mpg'], x=np.arange(32)) # initializing the parameter #0 to 773

#help(plt.bar)
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# # density plots

# %%
#hexogonal binning
#help(plt.hexbin)
plt.hexbin(mtcars["hp"],mtcars["mpg"],gridsize=20);plt.xlabel("HP");plt.ylabel("mpg");plt.title("Hexogonal Binning")
# Out:
# Text(0.5, 1.0, 'Hexogonal Binning')

# %%
#Violin Plot
#help(plt.violinplot)
plt.violinplot(mtcars["mpg"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x12ba08850>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x12b7a0950>,
#  'cmins': <matplotlib.collections.LineCollection at 0x12b946750>,
#  'cbars': <matplotlib.collections.LineCollection at 0x12ba08b90>}

# %% [markdown]
# #### Visualizing data with pandas

# %%
#Create a small DataFrame 
import pandas as pd
df = pd.DataFrame(index=['Atiya', 'Abbas', 'Cornelia','Stephanie', 'Monte'],
                   data={'Apples':[20, 10, 40, 20, 50],'Oranges':[35, 40, 25, 19, 33]})

# %%
df
# Out:
#            Apples  Oranges
# Atiya          20       35
# Abbas          10       40
# Cornelia       40       25
# Stephanie      20       19
# Monte          50       33

# %%
color=['.2',".7"]
ax = df.plot.bar(color=['.7','.3'], figsize=(16,4))
#ax.get_figure()

# %%
#Density plot
ax = df.plot.kde(color=['.2',".7"], figsize=(16,4))

# %%
#Let's plot a line plot, scatter plot, and a bar plot in a single figure
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('Two Variable Plots')
df.plot.line(ax=ax1, title='Line plot')
df.plot.scatter(x='Apples', y='Oranges',ax=ax2, title='Scatterplot')
df.plot.bar(color=color, ax=ax3, title='Bar plot')
# Out:
# /Users/srinivasgurrala/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'Bar plot'}>

# %%
##Let's put a KDE, boxplot, and histogram in the same figure as well

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('One Variable Plots', size=20, y=1.02)
df.plot.kde(color=color, ax=ax1, title='KDE plot')
df.plot.box(ax=ax2, title='Boxplot')
df.plot.hist(color=color, ax=ax3, title='Histogram')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
df.sort_values('Apples').plot.line(x='Apples', y='Oranges',ax=ax1)
df.plot.bar(x='Apples', y='Oranges', ax=ax2,color='blue')
df.plot.kde(x='Apples', ax=ax3)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
flights = pd.read_csv('flights.csv')

# %%
flights
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
#Before we start plotting, 
#let's calculate the number of diverted, canceled, delayed, and ontime flights

# %%
cols = ['DIVERTED', 'CANCELLED', 'DELAYED']

# %%
(flights
 .assign(DELAYED=flights['ARR_DELAY'].ge(15).astype(int),
    ON_TIME=lambda df_:1 - df_[cols].any(axis=1))
.select_dtypes(int)
.sum())
# Out:
# MONTH          363858
# DAY            918447
# WEEKDAY        229690
# SCHED_DEP    81186009
# DIST         51057671
# SCHED_ARR    90627495
# DIVERTED          137
# CANCELLED         881
# DELAYED         11685
# ON_TIME         45789
# dtype: int64

# %%
fig, ax_array = plt.subplots(2, 3, figsize=(18,8))
(ax1, ax2, ax3), (ax4, ax5, ax6) = ax_array
fig.suptitle('2015 US Flights - Univariate Summary', size=20)
ac = flights['AIRLINE'].value_counts()
ac.plot.barh(ax=ax1, title='Airline')
# Out:
# <AxesSubplot:title={'center':'Airline'}>

# %%
fig, ax_array = plt.subplots(2, 3, figsize=(18,8))
(ax1, ax2, ax3), (ax4, ax5, ax6) = ax_array
fig.suptitle('2015 US Flights - Univariate Summary', size=20)
ac = flights['AIRLINE'].value_counts()
ac.plot.barh(ax=ax1, title='Airline')


(flights['ORG_AIR'].value_counts().plot.bar(ax=ax2, rot=0, title='Origin City'))
(flights['DEST_AIR'].value_counts().head(10).plot.bar(ax=ax3, rot=0, title='Destination City'))

(flights.assign(DELAYED=flights['ARR_DELAY'].ge(15).astype(int),
 ON_TIME=lambda df_:1 - df_[cols].any(axis=1))[['DIVERTED', 'CANCELLED', 'DELAYED', 'ON_TIME']]
 .sum()
 .plot.bar(ax=ax4, rot=0,log=True, title='Flight Status'))

flights['DIST'].plot.kde(ax=ax5, xlim=(0, 3000), title='Distance KDE')
flights['ARR_DELAY'].plot.hist(ax=ax6,title='Arrival Delay',range=(0,200))
# Out:
# <AxesSubplot:title={'center':'Arrival Delay'}, ylabel='Frequency'>

# %% [markdown]
# # seaborn

# %%
employee = pd.read_csv('employee.csv',parse_dates=['HIRE_DATE', 'JOB_DATE'])

# %%
import seaborn as sns

# %%
#Let's make a bar chart of the count of each department with seaborn
fig, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y='DEPARTMENT', data=employee, ax=ax)
# Out:
# <AxesSubplot:xlabel='count', ylabel='DEPARTMENT'>

# %%
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#    HIRE_DATE   JOB_DATE
# 0 2006-06-12 2012-10-13
# 1 2000-07-19 2010-09-18
# ...

# %%
#Now, let's find the average salary for each race
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(y='RACE', x='BASE_SALARY', data=employee, ax=ax)
# Out:
# <AxesSubplot:xlabel='BASE_SALARY', ylabel='RACE'>

# %%
#Let's find the mean salary by RACE and GENDER:
fig, ax = plt.subplots(figsize=(18, 6))
sns.barplot(x='RACE', y='BASE_SALARY', hue='GENDER',
            ax=ax, data=employee, palette='Greys',
            order=['Hispanic/Latino',
                   'Black or African American',
                   'American Indian or Alaskan Native',
                   'Asian/Pacific Islander', 'Others',
                   'White'])
# Out:
# <AxesSubplot:xlabel='RACE', ylabel='BASE_SALARY'>

# %%
#Create a box plot of salary by RACE and GENDER with seaborn
fig, ax = plt.subplots(figsize=(16, 8))
sns.boxplot(x='GENDER', y='BASE_SALARY', data=employee,
            hue='RACE', palette='ocean', ax=ax)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='BASE_SALARY'>

# %%
#Multivariate analysis with seaborn Grids
emp = pd.read_csv('employee.csv',parse_dates=['HIRE_DATE', 'JOB_DATE'])

# %%
#create a column for years of experience
def yrs_exp(df_):
    days_hired = pd.to_datetime('12-1-2016') - df_.HIRE_DATE
    return days_hired.dt.days / 365.25

# %%
emp = (emp.assign(YEARS_EXPERIENCE=(yrs_exp)))

# %%
emp
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
emp[['HIRE_DATE', 'YEARS_EXPERIENCE']]

# %%
#create a scatter plot with a fitted regression line
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x='YEARS_EXPERIENCE', y='BASE_SALARY',data=emp, ax=ax)
# Out:
# <AxesSubplot:xlabel='YEARS_EXPERIENCE', ylabel='BASE_SALARY'>

# %%
#lmplot function to plot a seaborn grid that adds regression lines for
#males and females
grid = sns.lmplot(x='YEARS_EXPERIENCE', y='BASE_SALARY',hue='GENDER', palette='ocean',
                  scatter_kws={'s':10}, data=emp)
grid.fig.set_size_inches(8, 6)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips =sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("darkgrid", {'axes.grid' : True})
sns.lmplot(x= 'total_bill', y='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex',palette='Set1')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')
plt.show()

# %% [markdown]
# ## Univariate → “one variable” data visualization

# %%
#strip plot

sns.stripplot(y= 'tip', data=tips,jitter=True)
plt.ylabel('tip ($)')
plt.show()

# %%
#Grouping with stripplot()
sns.stripplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x='day', y='tip', data=tips, size=4,jitter=False)
plt.ylabel('tip ($)')
plt.show()

# %%
#Swarm plot

sns.swarmplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')
plt.ylabel('tip ($)')
plt.show()

# %%
#Changing orientation
sns.swarmplot(x='tip', y='day', data=tips, hue='sex',orient='h')
plt.xlabel('tip ($)')
plt.show()

# %% [markdown]
# ### Box and Violin plot

# %%
#plt.subplot(1,2,1)
sns.boxplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
# Out:
# Text(0, 0.5, 'tip ($)')

# %%
#plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')

plt.show()

# %%
##Combining plots

sns.violinplot(x='day', y='tip', data=tips, inner=None,color='lightgray')
sns.stripplot(x='day', y='tip', data=tips, size=4,jitter=True)
plt.ylabel('tip ($)')
plt.show()

# %% [markdown]
# ## Bivariate → “two variables” data visualization

# %%
#Joint plot

sns.jointplot(x= 'total_bill', y= 'tip', data=tips)
plt.show()

# %%
# Density plot
sns.jointplot(x='total_bill', y= 'tip', data=tips,kind='kde')
plt.show()

# %%
#Pair plot

sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#Covariance heat map of tips data
sns.heatmap(tips.corr(),vmin=-1, vmax=1, cmap='ocean')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Titanic data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #survival - Survival (0 = No; 1 = Yes)
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# name - Name
# sex - Sex
# age - Age
# sibsp - Number of Siblings/Spouses Aboard
# parch - Number of Parents/Children Aboard
# ticket - Ticket Number
# fare - Passenger Fare
# cabin - Cabin
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# ### Data types

# %%
print(data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# We can see that numbers are represted as int or float in this dataset and data type conversion is not needed here.

# %% [markdown]
# ### Proportion of target (Survived)

# %%
data.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %% [markdown]
# This dataset has a decent proportion of target class and it is not skewed to any one.

# %% [markdown]
# ### Visual Exploration

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='Survived', y="Age",  data=data);

# %% [markdown]
# Very less chances for age > 60+ to survive (except some outliers)

# %%
f, ax = plt.subplots(figsize=(7,3))
sns.barplot(x='Sex', y="Survived",  data=data);

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=data);

# %% [markdown]
# Gives clarity to the above finding that Male has very less chances for age > 60+

# %% [markdown]
# Number of female passengers survived is more than male passengers

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %% [markdown]
# Passenger Class 1 has high survival rate

# %%
sns.barplot(x="Pclass", y="Survived",hue="Sex", data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %% [markdown]
# More the siblings less the survival chance

# %%
sns.barplot(x="Parch", y="Survived", data=data);

# %%
#data["family"] = data["SibSp"] + data["Parch"]
#data["occumpanied"] = data["family"].apply(lambda x: 0 if x == 0 else 1)
#sns.barplot(x="Survived", y="occumpanied", data=data);

# %% [markdown]
# Those who are occumpanied by a family member (elder or siblings) had high survival rate

# %% [markdown]
# Passengers aged between 18-38 had high survival rate compared to others

# %%
survived = data.loc[data['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");

# %%
not_survived = data.loc[data['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
plt.title("Not Survived");

# %% [markdown]
# Infants had high survival rate and elderly passengers above 65+ were less likely to survive

# %%
sns.pairplot(data.dropna());

# %%
# Pclass vs Survive
grid = sns.FacetGrid(data, col='Survived', row='Pclass', size=2.4, aspect=1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()

# %%
# grid = sns.FacetGrid(train_df, col='Embarked', hue='Survived', palette={0: 'k', 1: 'w'})
grid = sns.FacetGrid(data, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5,ci=None)
grid.add_legend()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
grid = sns.FacetGrid(data, row='Pclass', col='Sex', )
grid.map(plt.hist, 'Age', alpha=.5, bins=40)
grid.add_legend()

# %%
sns.distplot(a=data[data['Embarked']=='C']['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()
plt.title("QueensTown")
sns.distplot(a=data[data['Embarked']=='Q']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()
plt.title("Southampton")
sns.distplot(a=data[data['Embarked']=='S']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()
#Most of the Passengers embarked from Southampton

# %%
#Plotting correlation by using heatmap
sns.heatmap(data.corr(),cmap='CMRmap')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>
